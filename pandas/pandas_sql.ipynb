# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('data/sncat.db')
df = pd.read_sql('SELECT * FROM mysncat',conn)

# %%
df.describe()
# Out:
#                  mjd             snid       snra      sndec          z  \
# count      10.000000        10.000000  10.000000  10.000000  10.000000
# mean   570124.650000  10039658.400000   0.087271   0.261853   1.425640
# std         1.581087   4822952.608345   0.000134   0.000140   0.692964
# min    570123.150000   3821204.000000   0.087109   0.261624   0.449000
# 25%    570123.150000   5918577.000000   0.087128   0.261827   1.110500
# 50%    570124.650000  10846664.000000   0.087337   0.261879   1.262900
# 75%    570126.150000  13594393.000000   0.087384   0.261900   2.044600
# max    570126.150000  16017454.000000   0.087399   0.262033   2.261200
#
#                   t0          c         x1         x0      mag_u     mag_g  \
# count      10.000000  10.000000  10.000000  10.000000   3.000000   2.00000
# mean   570126.807860  -0.175334  -0.027900   0.000004  36.611267  33.33880
# std        72.516893   0.210345   1.683213   0.000007   1.603372   0.06166
# min    570041.556900  -0.485950  -2.685500   0.000000  35.663200  33.29520
# 25%    570085.888000  -0.288100  -0.100600   0.000000  35.685650  33.31700
# 50%    570091.475200  -0.110505   0.054500   0.000001  35.708100  33.33880
# 75%    570192.864300  -0.099549   0.254700   0.000002  37.085300  33.36060
# max    570222.254900   0.107433   2.337400   0.000018  38.462500  33.38240
#
#            mag_r      mag_i      mag_z      mag_y
# count   4.000000   6.000000   9.000000   8.000000
# mean   29.609025  34.146833  38.256733  39.824437
# std     4.812813  12.024257  13.217000  12.111488
# min    25.345200  24.990500  26.197800  25.794700
# 25%    25.733175  25.970075  26.668800  29.861550
# 50%    28.932900  27.618300  30.288400  40.649600
# 75%    32.808750  44.124400  49.539800  50.070450
# max    35.225100  49.606800  54.475800  52.575000

# %%
df.head()
# Out:
#          id        mjd      snid      snra     sndec       z           t0  \
# 0  obshist0  570123.15   5918577  0.087109  0.261624  0.4490  570192.8643
# 1  obshist1  570123.15  10846664  0.087384  0.262033  2.0446  570091.4752
# 2  obshist2  570123.15  16017454  0.087128  0.261827  2.2612  570041.5569
# 3  obshist3  570123.15  13594393  0.087337  0.261879  1.2629  570085.8880
# 4  obshist4  570123.15   3821204  0.087399  0.261900  1.1105  570222.2549
#
#           c      x1        x0    mag_u    mag_g    mag_r    mag_i    mag_z  \
# 0 -0.099549 -0.1006  0.000018      NaN      NaN      NaN  49.6068  49.5398
# 1 -0.485950 -2.6855  0.000000      NaN      NaN  25.3452  24.9905  26.6688
# 2 -0.110505  2.3374  0.000000  35.7081  33.3824  35.2251      NaN  30.2884
# 3  0.107433  0.2547  0.000001  38.4625      NaN  32.0033  27.5594  26.1978
# 4 -0.288100  0.0545  0.000002      NaN      NaN      NaN      NaN  54.4758
#
#      mag_y
# 0  49.2356
# 1      NaN
# 2  32.0636
# 3  25.7947
# 4  52.5750

# %%
grouped = df.groupby('snid')
snids = grouped.groups.keys()

# %%
grouped.groups[snids[0]]
# Out:
# [1, 8]

# %%
df.loc[grouped.groups[snids[0]]][['mag_r','mag_i','mag_z','mag_y']]
# Out:
#      mag_r    mag_i    mag_z  mag_y
# 1  25.3452  24.9905  26.6688    NaN
# 8  25.8625  25.4403  26.7419    NaN
