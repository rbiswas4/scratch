# %%
import pandas as pd
import numpy as np

# %%
fname = 'data/SNIaCat_0.txt'

# %% [markdown]
# ### Read a CSV file into a pandas dataframe

# %%
df = pd.read_csv(fname)

# %% [markdown]
# #### Display dataframe

# %%
df
# Out:
#       #snid      snra     sndec       z           t0         c      x1  \
# 0   5918577  0.087109  0.261624  0.4490  570192.8643 -0.099549 -0.1006
# 1  13594393  0.087337  0.261879  1.2629  570085.8880  0.107433  0.2547
# 2   3821204  0.087399  0.261901  1.1105  570222.2549 -0.288100  0.0545
# 3  10846664  0.087384  0.262033  2.0446  570091.4752 -0.485950 -2.6855
# 4  16017454  0.087128  0.261827  2.2612  570041.5569 -0.110505  2.3374
#
#          x0     mag_u     mag_g     mag_r     mag_i    mag_z     mag_y
# 0  0.000018       nan       nan       nan   49.6068  49.5398   49.2356
# 1  0.000001   38.4625       nan   32.0033   27.5594  26.1978   25.7947
# 2  0.000002       nan       nan       nan       nan  54.4758   52.5750
# 3  0.000000       nan       nan   25.3452   24.9905  26.6688       nan
# 4  0.000000   35.7081   33.3824   35.2251       nan  30.2884   32.0636

# %% [markdown]
# Note that the dataframe does not interpret the leading hash as a comment character. The following takes care of it

# %%
df = df.rename(columns={'#snid':'snid'})

# %%
df
# Out:
#        snid      snra     sndec       z           t0         c      x1  \
# 0   5918577  0.087109  0.261624  0.4490  570192.8643 -0.099549 -0.1006
# 1  13594393  0.087337  0.261879  1.2629  570085.8880  0.107433  0.2547
# 2   3821204  0.087399  0.261901  1.1105  570222.2549 -0.288100  0.0545
# 3  10846664  0.087384  0.262033  2.0446  570091.4752 -0.485950 -2.6855
# 4  16017454  0.087128  0.261827  2.2612  570041.5569 -0.110505  2.3374
#
#          x0     mag_u     mag_g     mag_r     mag_i    mag_z     mag_y
# 0  0.000018       nan       nan       nan   49.6068  49.5398   49.2356
# 1  0.000001   38.4625       nan   32.0033   27.5594  26.1978   25.7947
# 2  0.000002       nan       nan       nan       nan  54.4758   52.5750
# 3  0.000000       nan       nan   25.3452   24.9905  26.6688       nan
# 4  0.000000   35.7081   33.3824   35.2251       nan  30.2884   32.0636

# %%
df.snid.loc[5918577]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-eb6e36581a89> in <module>()
# ----> 1 df.snid.loc[5918577]
#
# /usr/local/manual/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1127             return self._getitem_tuple(key)
#    1128         else:
# -> 1129             return self._getitem_axis(key, axis=0)
#    1130
#    1131     def _getitem_axis(self, key, axis=0, validate_iterable=False):
#
# /usr/local/manual/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis, validate_iterable)
#    1259             return self.obj.iloc[tuple(indexer)]
#    1260         else:
# -> 1261             self._has_valid_type(key, axis)
#    1262             return self._get_label(key, axis=axis)
#    1263
#
# ...
